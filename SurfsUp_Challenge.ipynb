# %%
# Dependencies
import numpy as np

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, MetaData, Table

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# ## D1: Determine the Summary Statistics for June

# %%
#  Create a meta data object
metadata = MetaData()
# Create a table object for  the `measurement` table
Measure_table = Table('measurement', metadata, autoload=True, autoload_with=engine)
# Check columns in table
print(Measure_table.columns.keys())
# Out:
# ['id', 'station', 'date', 'prcp', 'tobs']

# %%
# 1. Import the sqlalchemy extract function.
from sqlalchemy import extract

date_str = '06'

# 2. Write a query that filters the Measurement table to retrieve the temperatures for the month of June. 
June_Temps= session.query(Measurement.tobs).filter(func.strftime('%m', Measurement.date) == date_str).order_by(Measurement.date).all()
June_Temps
# Out:
# [(78.0),
#  (74.0),
#  (73.0),
#  (77.0),
#  (69.0),
#  (76.0),
#  (71.0),
#  (74.0),
#  (70.0),
#  (76.0),
#  (76.0),
#  (72.0),
#  (76.0),
#  (70.0),
#  (76.0),
#  (71.0),
#  (76.0),
#  (78.0),
#  (78.0),
#  (75.0),
#  (74.0),
#  (77.0),
#  (67.0),
#  (76.0),
#  (72.0),
#  (78.0),
#  (73.0),
#  (76.0),
#  (75.0),
#  (73.0),
#  (75.0),
#  (70.0),
#  (73.0),
#  (72.0),
#  (74.0),
#  (68.0),
#  (77.0),
#  (74.0),
#  (72.0),
#  (73.0),
#  (78.0),
#  (76.0),
#  (79.0),
#  (79.0),
#  (78.0),
#  (75.0),
#  (75.0),
#  (73.0),
#  (77.0),
#  (77.0),
#  (79.0),
#  (74.0),
#  (77.0),
#  (75.0),
#  (74.0),
#  (76.0),
#  (77.0),
#  (71.0),
#  (69.0),
#  (75.0),
#  (78.0),
#  (75.0),
#  (75.0),
#  (79.0),
#  (77.0),
#  (73.0),
#  (77.0),
#  (71.0),
#  (78.0),
#  (75.0),
#  (73.0),
#  (79.0),
#  (72.0),
#  (78.0),
#  (73.0),
#  (80.0),
#  (75.0),
#  (79.0),
#  (75.0),
#  (75.0),
#  (77.0),
#  (72.0),
#  (78.0),
#  (75.0),
#  (75.0),
#  (78.0),
#  (83.0),
#  (76.0),
#  (77.0),
#  (76.0),
# ...

# %%
#  3. Convert the June temperatures to a list.
June_List = list(np.ravel(June_Temps))
June_List
# Out:
# [78.0,
#  74.0,
#  73.0,
#  77.0,
#  69.0,
#  76.0,
#  71.0,
#  74.0,
#  70.0,
#  76.0,
#  76.0,
#  72.0,
#  76.0,
#  70.0,
#  76.0,
#  71.0,
#  76.0,
#  78.0,
#  78.0,
#  75.0,
#  74.0,
#  77.0,
#  67.0,
#  76.0,
#  72.0,
#  78.0,
#  73.0,
#  76.0,
#  75.0,
#  73.0,
#  75.0,
#  70.0,
#  73.0,
#  72.0,
#  74.0,
#  68.0,
#  77.0,
#  74.0,
#  72.0,
#  73.0,
#  78.0,
#  76.0,
#  79.0,
#  79.0,
#  78.0,
#  75.0,
#  75.0,
#  73.0,
#  77.0,
#  77.0,
#  79.0,
#  74.0,
#  77.0,
#  75.0,
#  74.0,
#  76.0,
#  77.0,
#  71.0,
#  69.0,
#  75.0,
#  78.0,
#  75.0,
#  75.0,
#  79.0,
#  77.0,
#  73.0,
#  77.0,
#  71.0,
#  78.0,
#  75.0,
#  73.0,
#  79.0,
#  72.0,
#  78.0,
#  73.0,
#  80.0,
#  75.0,
#  79.0,
#  75.0,
#  75.0,
#  77.0,
#  72.0,
#  78.0,
#  75.0,
#  75.0,
#  78.0,
#  83.0,
#  76.0,
#  77.0,
#  76.0,
#  81.0,
#  75.0,
#  78.0,
#  75.0,
#  74.0,
#  70.0,
#  76.0,
#  74.0,
#  78.0,
#  78.0,
#  76.0,
#  74.0,
#  78.0,
#  79.0,
#  77.0,
#  77.0,
#  73.0,
#  73.0,
#  74.0,
#  70.0,
#  71.0,
# ...

# %%
# 4. Create a DataFrame from the list of temperatures for the month of June.

# %%
# 5. Calculate and print out the summary statistics for the June temperature DataFrame.

# %% [markdown]
# ## D2: Determine the Summary Statistics for December

# %%
# 6. Write a query that filters the Measurement table to retrieve the temperatures for the month of December.

# %%
# 7. Convert the December temperatures to a list.

# %%
# 8. Create a DataFrame from the list of temperatures for the month of December.

# %%
# 9. Calculate and print out the summary statistics for the Decemeber temperature DataFrame.
